# %%
import datetime

# %% [markdown]
# # markdown

# %%
print(datetime.datetime.now())
# Out:
# 2026-04-27 07:36:19.100231

# %% [markdown]
# **This is bold**

# %% [markdown]
# ### Use methods of date

# %%
name = input("Enter your name :")

# %%
print(name)
# Out:
# Srikanth

# %%
if name == 'end':
        print('The End')
else:
  print("Name = ", name)
# Out:
# Name =  Sri

# %%
print('Over')
# Out:
# Over
